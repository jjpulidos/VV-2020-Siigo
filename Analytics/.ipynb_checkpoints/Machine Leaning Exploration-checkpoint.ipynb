# %% [markdown]
# # Mean Money Collected

# %%
import pandas as pd
from fbprophet import Prophet

df_mean_money = pd.read_csv('mean_money_collected_daily.csv')
df_mean_money = df.fillna(0)
df_mean_money.columns = ['ds', 'y']
df_mean_money
# Out:
#              ds              y
# 0    2017-08-11  302534.880000
# 1    2017-08-12  214032.865000
# 2    2017-08-13       0.000000
# 3    2017-08-14       0.000000
# 4    2017-08-15  418641.365000
# ..          ...            ...
# 907  2020-02-04  350487.664000
# 908  2020-02-05  501202.755000
# 909  2020-02-06  394393.485000
# 910  2020-02-07   96746.933333
# 911  2020-02-08  615663.955000
#
# [912 rows x 2 columns]

# %%
model_mean_money = Prophet(daily_seasonality=True)
model_mean_money.fit(df_mean_money)

# %%
future_mean_money = model_mean_money.make_future_dataframe(periods=7)
future_mean_money.tail()
# Out:
#             ds
# 914 2020-02-11
# 915 2020-02-12
# 916 2020-02-13
# 917 2020-02-14
# 918 2020-02-15

# %%
forecast_mean_money = model_mean_money.predict(future_mean_money)
forecast_mean_money[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds           yhat     yhat_lower     yhat_upper
# 914 2020-02-11  334099.510763   99941.516708  571805.182457
# 915 2020-02-12  352059.959698  128717.457532  569593.763254
# 916 2020-02-13  350780.381480  118453.077446  586658.757774
# 917 2020-02-14  332465.369492  108665.899798  570210.121152
# 918 2020-02-15  334131.043269   99478.183218  566019.751978

# %%
fig1 = model_mean_money.plot(forecast_mean_money)

# %%
fig2 = model_mean_money.plot_components(forecast_mean_money)

# %%
forecast_mean_money.iloc[912:913]
# Out:
#             ds          trend     yhat_lower     yhat_upper    trend_lower  \
# 912 2020-02-09  323650.561029  121572.903858  585009.078604  323650.561029
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 912  323650.561029     15000.80797           15000.80797
#
#      additive_terms_upper         daily  ...       weekly  weekly_lower  \
# 912           15000.80797 -10807.292002  ... -1809.317075  -1809.317075
#
#      weekly_upper        yearly  yearly_lower  yearly_upper  \
# 912  -1809.317075  27617.417047  27617.417047  27617.417047
#
#      multiplicative_terms  multiplicative_terms_lower  \
# 912                   0.0                         0.0
#
#      multiplicative_terms_upper           yhat
# 912                         0.0  338651.368999
#
# [1 rows x 22 columns]

# %% [markdown]
# # Total Money Collected Per Day

# %%
df_total_money = pd.read_csv('total_money_collected_daily.csv')
df_total_money = df_total_money.fillna(0)
df_total_money.columns = ['ds', 'y']
df_total_money

model_total_money = Prophet(daily_seasonality=True)
model_total_money.fit(df_total_money)
future_total_money = model_total_money.make_future_dataframe(periods=7)
forecast_total_money = model_total_money.predict(future_total_money)
fig3 = model_total_money.plot(forecast_total_money)

# %%
fig4 = model_total_money.plot_components(forecast_total_money)

# %%
forecast_total_money.iloc[912:913]
# Out:
#             ds          trend     yhat_lower    yhat_upper    trend_lower  \
# 912 2020-02-09  937521.507983  167124.614504  1.715275e+06  937521.507983
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 912  937521.507983   -30619.808391         -30619.808391
#
#      additive_terms_upper          daily  ...        weekly  weekly_lower  \
# 912         -30619.808391 -153277.333402  ...  73016.609474  73016.609474
#
#      weekly_upper        yearly  yearly_lower  yearly_upper  \
# 912  73016.609474  49640.915537  49640.915537  49640.915537
#
#      multiplicative_terms  multiplicative_terms_lower  \
# 912                   0.0                         0.0
#
#      multiplicative_terms_upper           yhat
# 912                         0.0  906901.699592
#
# [1 rows x 22 columns]

# %% [markdown]
# # Invoices Ammount per Day

# %%
df_invoice_ammount = pd.read_csv('invoice_ammount_collected_daily.csv')
df_invoice_ammount = df_invoice_ammount.fillna(0)
df_invoice_ammount.columns = ['ds', 'y']
df_invoice_ammount

model_invoice_ammount = Prophet(daily_seasonality=True)
model_invoice_ammount.fit(df_invoice_ammount)
future_invoice_ammount = model_invoice_ammount.make_future_dataframe(periods=7)
forecast_invoice_ammount = model_invoice_ammount.predict(future_invoice_ammount)
fig5 = model_invoice_ammount.plot(forecast_invoice_ammount)

# %%
fig6 = model_invoice_ammount.plot_components(forecast_invoice_ammount)

# %%
# If you are optimistic, apply a ceil function to yhat result
# If you are pesimist, apply a floor function to yhat result
forecast_invoice_ammount.iloc[912:913]
# Out:
#             ds   trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 912 2020-02-09  2.9321    0.608687    4.194351       2.9321       2.9321
#
#      additive_terms  additive_terms_lower  additive_terms_upper     daily  \
# 912       -0.524331             -0.524331             -0.524331 -0.697607
#
#      ...    weekly  weekly_lower  weekly_upper    yearly  yearly_lower  \
# 912  ...  0.153574      0.153574      0.153574  0.019702      0.019702
#
#      yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 912      0.019702                   0.0                         0.0
#
#      multiplicative_terms_upper      yhat
# 912                         0.0  2.407769
#
# [1 rows x 22 columns]

# %% [markdown]
# # Customers Activity Ratio per Day

# %%
df_customers_ratio = pd.read_csv('customers_ratio_collected_daily.csv')
df_customers_ratio = df_customers_ratio.fillna(0)
df_customers_ratio.columns = ['ds', 'y']
df_customers_ratio

model_customers_ratio = Prophet(daily_seasonality=True)
model_customers_ratio.fit(df_customers_ratio)
future_customers_ratio = model_customers_ratio.make_future_dataframe(periods=7)
forecast_customers_ratio = model_customers_ratio.predict(future_customers_ratio)
fig7 = model_customers_ratio.plot(forecast_customers_ratio)
# Out:
# /home/woombatcg/anaconda3/envs/prophet/lib/python3.7/site-packages/pystan/misc.py:399: FutureWarning:
#
# Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.

# %%
fig8 = model_customers_ratio.plot_components(forecast_customers_ratio)

# %%
forecast_customers_ratio.iloc[815:816]
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 815 2020-02-09  5.797672    1.999753    8.429382     5.797672     5.797672
#
#      additive_terms  additive_terms_lower  additive_terms_upper     daily  \
# 815       -0.583405             -0.583405             -0.583405 -1.000567
#
#      ...    weekly  weekly_lower  weekly_upper    yearly  yearly_lower  \
# 815  ...  0.462515      0.462515      0.462515 -0.045353     -0.045353
#
#      yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 815     -0.045353                   0.0                         0.0
#
#      multiplicative_terms_upper      yhat
# 815                         0.0  5.214267
#
# [1 rows x 22 columns]
